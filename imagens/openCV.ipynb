# %% [markdown]
# ## Aula 03 - OpenCV

# %%
# Configuração Básica para utilizar o OpenCV no Notebook Colab Google
# Baixe a imagem de teste e os arquivos utils
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/maxbassoul/processamento-de-imagens/main/foto2.jpeg \
    -O foto2.jpeg
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/maxbassoul/opencv-learning/main/common.py \
    -O common.py

# Essas importações permitem que você use o opencv
import cv2 #opencv itself
import common #some useful opencv functions
import numpy as np # matrix manipulations

# o seguinte tem a ver com este código de notebook interativo
# %matplotlib inline 
from matplotlib import pyplot as plt # isso permite que você desenhe imagens em linha nos blocos de anotações
import pylab # isso permite que você controle o tamanho da figura
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # isso controla o tamanho da figura no notebook
# Out:
# --2022-03-10 00:18:42--  https://raw.githubusercontent.com/maxbassoul/processamento-de-imagens/main/foto2.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85953 (84K) [image/jpeg]
# Saving to: ‘foto2.jpeg’
#
# foto2.jpeg          100%[===================>]  83.94K  --.-KB/s    in 0.02s
#
# 2022-03-10 00:18:42 (3.76 MB/s) - ‘foto2.jpeg’ saved [85953/85953]
#
# --2022-03-10 00:18:42--  https://raw.githubusercontent.com/maxbassoul/opencv-learning/main/common.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6572 (6.4K) [text/plain]
# Saving to: ‘common.py’
#
# common.py           100%[===================>]   6.42K  --.-KB/s    in 0s
#
# 2022-03-10 00:18:42 (71.1 MB/s) - ‘common.py’ saved [6572/6572]

# %%
teste = cv2.imread('foto2.jpeg')
plt.imshow(teste)
b,g,r=cv2.split(teste)

# %%
print("Altura")
print(teste.shape[0])

print("Largura")
print(teste.shape[1])

print("Canais")
print(teste.shape[2])
# Out:
# Altura
# 670
# Largura
# 670
# Canais
# 3

# %%
(b, g, r) = teste[50, 250]
print("Cor do pixel em (50, 250)")
print("Vermelho: ", r)
print("Verde: ", g)
print("Azul: ", b)
# Out:
# Cor do pixel em (50, 250)
# Vermelho:  67
# Verde:  64
# Azul:  45

# %%
# Baixe a imagem de teste e os arquivos utils
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/maxbassoul/opencv-learning/main/foto2.jpeg \
    -O foto2.jpeg
# Out:
# --2022-03-10 00:35:35--  https://raw.githubusercontent.com/maxbassoul/opencv-learning/main/foto2.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162642 (159K) [image/jpeg]
# Saving to: ‘foto2.jpeg’
#
# foto2.jpeg          100%[===================>] 158.83K  --.-KB/s    in 0.04s
#
# 2022-03-10 00:35:36 (4.20 MB/s) - ‘foto2.jpeg’ saved [162642/162642]

# %%
# Lendo a imagem
ruido = cv2.imread('foto2.jpeg')
plt.imshow(ruido)

# Aplicando o filtro de mediana da biblioteca OpenCV
# que é importada como cv2 e atribuindo a variavel median
# utilizando uma mascara 5x5
median = cv2.medianBlur(ruido,5)

# Codigo reponsavel por plotar a imagem original e 
# o resultado lado a lado a nivel de comparacao
plt.subplot(121),plt.imshow(ruido),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Mediana')
plt.xticks([]), plt.yticks([])
plt.show()
